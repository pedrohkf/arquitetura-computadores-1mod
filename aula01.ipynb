# %% [markdown]
# <a href="https://colab.research.google.com/github/pedrohkf/arquitetura-computadores-1mod/blob/main/aula01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
lampada_acessa = True
print("A lampada está acessa?", lampada_acessa)

lampada_acessa = not lampada_acessa
print("A lampada está acessa?", lampada_acessa)
# Out:
# A lampada está acessa? True
# A lampada está acessa? False
